# %% [markdown]
# # Testing Functions
#
# * **Author:** Brian P Josey
# * **Date Created:** 2021-04-15
# * **Date Modified:** 2021-04-15
# * **Language:** Python 3.8.3
#
# I am using this notebook to test that the functions I wrote in `plotting_functions.py` work as intended. In order for this to work, I need to import the pandas and MatPlotLib libraries first.

# %%
#import matplotlib.pyplot as plt
#import numpy as np
#import pandas as pd

from plotting_functions import *

# %%
plot_xr_profile()

# %%
plot_xr_refl()

# %%
plot_pol_profile()

# %%
plot_pol_refl()
